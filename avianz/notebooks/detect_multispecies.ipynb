# %% [markdown]
# ## CLI command for detecting multiple species

# %%
# Look in AviaNZ.py for the cli flags

# Detect NIBK over a single directory
python AviaNZ.py -c -b -d "G:\kiwinui\Yiluo\DOC C66\20231019" -r "Kiwi (Nth Is Brown)" -w

# Detect NIBK and Owl over a single directory; save annotations in custom location; run using GPU
# double -r allows multi-species detection on one pass
# -asd is annotation save directory
# --gpu uses GPU for inference, not just training

python AviaNZ.py -c -b -d "G:\kiwinui\Yiluo\DOC C66\20230908" -r "Kiwi (Nth Is Brown)" -r "Morepork" -w -asd "D:\avianz\annotations_out" --gpu
